# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 12, 14, 16, 18])

# %%
coeff = np.polyfit(x, y, 2)
poly = np.poly1d(coeff)

# %%
plt.scatter(x, y)
x_line = np.linspace(min(x), max(x), 100)
y_fit = poly(x_line)
plt.plot(x_line, y_fit)
plt.show()

# %%
for i in range(6, 10):
    new_x = i
    predicted_y = poly(new_x)
    print(f"For x = {new_x} predicted y is {predicted_y}")
# Out:
# For x = 6 predicted y is 20.0
# For x = 7 predicted y is 22.0
# For x = 8 predicted y is 24.0
# For x = 9 predicted y is 26.0
